# %%
import numpy as np
import pandas as pd
from collections import Counter
from matplotlib import pyplot as plt
import os
import zipfile

# %%
# upload the data to Python

olympics = pd.read_csv('../datasets/athlete_events.csv')
regions = pd.read_csv('../datasets/noc_regions.csv')

# %%
print(olympics.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB
# None

# %%
olympics.loc[olympics.Age.isna(),:].head()
# Out:
#       ID                   Name Sex  Age  Height  Weight      Team  NOC  \
# 147   54  Mohamed Jamshid Abadi   M  NaN     NaN     NaN      Iran  IRI
# 152   58       Georgi Abadzhiev   M  NaN     NaN     NaN  Bulgaria  BUL
# 153   58       Georgi Abadzhiev   M  NaN     NaN     NaN  Bulgaria  BUL
# 162   66        Mohamed Abakkar   M  NaN   156.0    48.0     Sudan  SUD
# 212  102      Sayed Fahmy Abaza   M  NaN     NaN     NaN     Egypt  EGY
#
#            Games  Year  Season       City     Sport  \
# 147  1948 Summer  1948  Summer     London    Boxing
# 152  1924 Summer  1924  Summer      Paris   Cycling
# 153  1924 Summer  1924  Summer      Paris   Cycling
# 162  1972 Summer  1972  Summer     Munich    Boxing
# 212  1920 Summer  1920  Summer  Antwerpen  Football
#
#                                    Event Medal
# 147             Boxing Men's Heavyweight   NaN
# 152  Cycling Men's Road Race, Individual   NaN
# 153        Cycling Men's Road Race, Team   NaN
# ...

# %%
olympics.loc[olympics.NOC == 'URS',['NOC','Team']].head()
# Out:
#      NOC          Team
# 192  URS  Soviet Union
# 193  URS  Soviet Union
# 550  URS  Soviet Union
# 622  URS  Soviet Union
# 802  URS  Soviet Union

# %%
olympics.loc[olympics.NOC == 'FRG',['NOC','Team']].head()
# Out:
#       NOC          Team
# 674   FRG  West Germany
# 675   FRG  West Germany
# 1051  FRG  West Germany
# 1052  FRG  West Germany
# 1387  FRG  West Germany

# %%
olympics.loc[olympics.NOC == 'GDR',['NOC','Team']].head()
# Out:
#      NOC          Team
# 676  GDR  East Germany
# 677  GDR  East Germany
# 678  GDR  East Germany
# 679  GDR  East Germany
# 680  GDR  East Germany

# %%
olympics.loc[olympics.NOC == 'URS',['NOC','Team']] = ['RUS','Russia']

# %%
olympics.loc[olympics.NOC.isin(['FRG','GDR']),['NOC','Team']] = ['GER','Germany']

# %%
olympics.loc[olympics.Team == 'Bohemia',['NOC','Team']].count()
# Out:
# NOC     146
# Team    146
# dtype: int64

# %%
olympics.loc[olympics.Team == 'Czech Republic',['NOC','Team']].head()
# Out:
#       NOC            Team
# 1404  CZE  Czech Republic
# 1405  CZE  Czech Republic
# 1406  CZE  Czech Republic
# 1407  CZE  Czech Republic
# 1408  CZE  Czech Republic

# %%
olympics.loc[olympics.Team == 'Bohemia',['NOC','Team']] = ['CZE','Czech Republic']

# %%
olympics.loc[olympics.Medal.notna(),:].head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games  Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# ...
